# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
sns.set_theme(style="whitegrid")

data_path = "/Users/khali/Desktop/Coding Workspace/Flight Delay Prediction/data/raw/Airline_Delay_Cause.csv"
df=pd.read_csv(data_path)

print("Shape: " , df.shape , "Rows and Columns")
display(df.head())

df["delay_rate"] = df["arr_del15"] / df["arr_flights"]

df["date"] = pd.to_datetime(df[["year" , "month"]].assign(day=1)) #so this gets converted to like then date time thing


plt.figure(figsize=(10,5))
sns.boxplot(data=df, x = "carrier" , y = "delay_rate")
plt.title("Delay Rate Distribution by Carrier")
plt.ylabel("Delay Rate")
plt.xlabel("Carrier")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Shape:  (84, 21) Rows and Columns
#    year  month carrier              carrier_name airport  \
# 0  2025      1      UA  United Air Lines Network     ATL
# 1  2025      1      UA  United Air Lines Network     AUS
# 2  2025      1      UA  United Air Lines Network     BNA
# 3  2025      1      UA  United Air Lines Network     BOS
# 4  2025      1      UA  United Air Lines Network     BWI
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        567.0      108.0
# 1       Austin, TX: Austin - Bergstrom International        721.0      153.0
# 2             Nashville, TN: Nashville International        425.0       67.0
# 3                    Boston, MA: Logan International        919.0      114.0
# 4  Baltimore, MD: Baltimore/Washington Internatio...        256.0       43.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# ...

# %%
print("\nMissing Values: \n" , df.isnull().sum()) #no missing values

processed_Path = "/Users/khali/Desktop/Coding Workspace/Flight Delay Prediction/data/processed/Airline_Delay_Cause_Clean.csv"
df.to_csv(processed_Path , index = False)
print(f"\nCleaned data, along with Delay_Rate and Date is saved to: {processed_Path}")
# Out:
# Missing Values:
#  year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# delay_rate             0
# date                   0
# dtype: int64
#
# Cleaned data, along with Delay_Rate and Date is saved to: /Users/khali/Desktop/Coding Workspace/Flight Delay Prediction/data/processed/Airline_Delay_Cause_Clean.csv
